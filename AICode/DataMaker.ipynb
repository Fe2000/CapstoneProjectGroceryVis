# %%
import numpy as np                       # used for matrices
from PIL import Image                    # used to read images
from matplotlib import pyplot as plt     # used to display images inline
import cv2
import math
import os

# %%
path = "C://Users//Fernando//Desktop//DataVid//Videos"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
# prints all files
print(dir_list)
# Out:
# Files and directories in ' C://Users//Fernando//Desktop//DataVid//Videos ' :
# ...

# %%
AllCount = 0

# %%
for i in dir_list:
    path = 'Videos//'+i
    print(path)
    vidcap = cv2.VideoCapture(path)
    success,image = vidcap.read()
    while success:
        cv2.imwrite("Frames/Mframe%d.jpg" % AllCount, image)     # save frame as JPEG file      
        success,image = vidcap.read()
        #print('Read a new frame: ', success)
        AllCount += 1
# Out:
# Videos//All.mov
# Videos//All1.mov
# Videos//All3.mov
# Videos//Apple.mov
# Videos//Apple1.mov
# Videos//Apple2.mov
# Videos//Apple4.mov
# Videos//AppleEggsMilkPasta.mov
# Videos//AppleMilkBreadEggsPeanut82.mov
# Videos//AppleMilkEggaPeanutBread05.mov
# Videos//ApplePastaMilkEggsBread4.mov
# Videos//ApplePastaMilkEggsPea1.mov
# Videos//ApplePastaPeanut.mov
# Videos//ApplePastaPeanut1.mov
# Videos//ApplePastaPeanut3.mov
# Videos//Bread.mov
# Videos//Bread1.mov
# Videos//Bread2.mov
# Videos//Bread3.mov
# Videos//Bread4.mov
# Videos//BreadEggsMilk1.mov
# Videos//BreadEggsMilk2.mov
# Videos//BreadPeanut.mov
# Videos//BreadPeanut1.mov
# Videos//BreadPeanut3.mov
# Videos//BreadPeanut4.mov
# Videos//Eggs.mov
# Videos//Eggs1.mov
# Videos//Eggs2.mov
# Videos//Eggs3.mov
# Videos//EggsBreadMilk.mov
# Videos//EggsMilkBreadPeanutPasta7.mov
# Videos//Milk.mov
# Videos//Milk1.mov
# Videos//Milk11.mov
# Videos//Milk2.mov
# Videos//Milk4.mov
# Videos//Milk5.mov
# Videos//Milk8.mov
# ...

# %%
# Every Frame
vidcap = cv2.VideoCapture('Milk.mov')
success,image = vidcap.read()
while success:
    cv2.imwrite("Frames/Mframe%d.jpg" % AllCount, image)     # save frame as JPEG file      
    success,image = vidcap.read()
    #print('Read a new frame: ', success)
    tempCount += 1

# %%
import roboflow

# %%
path1 = "C://Users//Fernando//Desktop//DataVid//Frames"
dir_list = os.listdir(path1)
 
print("Files and directories in '", path, "' :")
 
# prints all files
print(dir_list)
# Out:
# Files and directories in ' Videos//Peanut5.mov ' :
# ...
